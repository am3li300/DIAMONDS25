# %%
import numpy as np

data = np.genfromtxt('cross_validation/rankings/allergy_STRING/3_allergy_cross_validation_2.out', delimiter='\t', skip_header=0, usecols=range(1, 1))
print(data[0])
# Out:
# [       nan 0.00714615]

# %%
data = data[:,1]

# %%
data
# Out:
# array([7.14615075e-03, 7.14392697e-03, 5.98867933e-03, ...,
#        9.10077876e-08, 9.10077876e-08, 9.10019731e-08])

# %%
import matplotlib.pyplot as plt

# Example data

# Plot histogram with log scale on y-axis
plt.hist(data, bins=50, log=True, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency (log scale)')
plt.title('Histogram with Log Scale')
plt.show()
