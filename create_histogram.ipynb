# %%
import numpy as np

data = np.genfromtxt('cross_validation/rankings/SZ_STRING_constant_k_20_disease_genes/3_SZ_cross_validation_0.out', delimiter='\t', skip_header=0, usecols=range(1, 1))
# data = np.genfromtxt('cross_validation/rankings/allergy_STRING_supervised/3_allergy_cross_validation_1.out', delimiter='\t', skip_header=0, usecols=range(1, 1))
print(data[0])
# Out:
# [      nan 0.0047728]

# %%
data = data[0:,1]

# %%
data
# Out:
# array([4.77280201e-03, 4.76739966e-03, 4.76452970e-03, ...,
#        8.92037415e-08, 8.92037415e-08, 8.91897899e-08])

# %%
import matplotlib.pyplot as plt

# Example data

# Plot histogram with log scale on y-axis
plt.hist(data, bins=50, log=True, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency (log scale)')
plt.title('Histogram with Log Scale')
plt.show()
